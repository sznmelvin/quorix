# %% [markdown]
# ## Crypto News Sentiment Analyzer

# %% [markdown]
# ### Function for fetching news articles

# %%
import requests
import pandas as pd
from datetime import datetime

def fetch_crypto_news(api_key, limit=100):
    # Use the correct base URL for CryptoCompare news API
    base_url = "https://min-api.cryptocompare.com/data/v2/news/?lang=EN"
    
    headers = {'authorization': f'Apikey {api_key}'}
    
    params = {
        'limit': limit  # Only the limit is necessary, remove sortOrder
    }
    
    try:
        response = requests.get(base_url, headers=headers, params=params)
        response.raise_for_status()  # This will raise an error for a non-200 status code
        news_data = response.json()
        
        # Check if 'Response' exists and handle the response accordingly
        if 'Data' in news_data:
            return news_data['Data']  # The actual news articles are under 'Data'
        else:
            print(f"Error: {news_data.get('Message', 'Unexpected response structure')}")
            return None
    
    except requests.RequestException as e:
        print(f"An error occurred: {e}")
        return None

def news_to_dataframe(news_articles):
    if not news_articles:
        print("No news articles to process.")
        return pd.DataFrame()
    
    # Extract relevant fields from each article
    data = [{
        'title': article['title'],
        'source': article['source'],
        'published_on': datetime.fromtimestamp(article['published_on']),
        'url': article['url'],
        'body': article['body']
    } for article in news_articles]
    
    df = pd.DataFrame(data)
    
    df = df.sort_values('published_on', ascending=False).reset_index(drop=True)
    
    return df

def display_news_dataframe(df):
    if df.empty:
        print("No news articles to display.")
        return
    
    # Display each article
    for index, row in df.iterrows():
        print(f"\nTitle: {row['title']}")
        print(f"Source: {row['source']}")
        print(f"Published: {row['published_on']}")
        print(f"URL: {row['url']}")
        print(f"Summary: {row['body'][:200]}...")  # Display first 200 characters of the body
        print("-" * 80)

if __name__ == "__main__":
    # Replace 'YOUR_API_KEY' with your actual CryptoCompare API key
    api_key = 'cac28894fc36efc1f0217705d94bdb1e632ff76f49eefbf473919c07f6a4f845'
    
    news = fetch_crypto_news(api_key)

# %%
news_df = news_to_dataframe(news)
display_news_dataframe(news_df)
# Out:
# Title: Rich Dad Poor Dad Author Tells Us Why Bitcoin Will See $500,000 Next Year
# Source: zycrypto
# Published: 2024-09-21 18:16:26
# URL: https://zycrypto.com/rich-dad-poor-dad-author-tells-us-why-bitcoin-will-see-500000-next-year/
# Summary: Robert Kiyosaki, the best-selling author of “Rich Dad Poor Dad” speculates that Bitcoin is heading to six figures as early as next year....
# --------------------------------------------------------------------------------
#
# Title: Hashgraph Association to Explore Five Crypto Use Cases in Qatar
# Source: btcpulse
# Published: 2024-09-21 18:03:00
# URL: https://btc-pulse.com/hashgraph-association-explore-crypto-use-cases-qatar/
# Summary: The Hashgraph Association partners with Qatar to explore five digital asset use cases, including equity, Sukuk, and real estate, over the next year....
# --------------------------------------------------------------------------------
#
# Title: Polkadot Price Prediction 2024-2030: A Bullish Pattern?
# Source: cryptopolitan
# Published: 2024-09-21 18:01:31
# URL: https://www.cryptopolitan.com/polkadot-price-prediction/
# Summary: Key takeaways: Polkadot (DOT), known for its innovative multichain protocol architecture, demonstrates significant growth and resilience in a fluctuating cryptocurrency market. This performance indica...
# --------------------------------------------------------------------------------
#
# Title: US Judge Orders Convicted Fraudster To Pay $36,000,000 in Connection to Crypto and Forex Schemes
# Source: dailyhodl
# Published: 2024-09-21 18:00:31
# URL: https://dailyhodl.com/2024/09/21/us-judge-orders-convicted-fraudster-to-pay-36000000-in-connection-to-crypto-and-forex-schemes/
# Summary: A US judge this week ordered a convicted fraudster to pay a $5 million civil penalty and $31 million in restitution related to a massive crypto and forex scheme he orchestrated. New York resident Will...
# --------------------------------------------------------------------------------
#
# Title: Is XRP supply running low? Here’s what it means for retail investors
# Source: ambcrypto
# Published: 2024-09-21 18:00:28
# URL: https://ambcrypto.com/is-xrp-supply-running-low-heres-what-it-means-for-retail-investors/
# Summary: XRP supply is rapidly shrinking as institutional accumulation rises, leaving retail investors with limited options....
# --------------------------------------------------------------------------------
#
# Title: Analyst Who Predicted The Bitcoin Rally Reveals Time To Sell
# Source: newsbtc
# Published: 2024-09-21 18:00:25
# URL: https://www.newsbtc.com/news/bitcoin/bitcoin-rally-time-to-sell/
# Summary: Bitcoin has performed well in the past few days after experiencing a strong downturn in the first two weeks of September. This rally kickstarted in the middle of this week after the Fed decided to sla...
# --------------------------------------------------------------------------------
#
# Title: Bitcoin (BTC) BlackRock Victory Commented on By Top Bitcoiner Angel Investor
# Source: utoday
# Published: 2024-09-21 18:00:00
# URL: https://u.today/bitcoin-btc-blackrock-victory-commented-on-by-top-bitcoiner-angel-investor
# Summary: Prominent Bitcoin investor Anthony Pompliano shares take on recent IBIT approval...
# --------------------------------------------------------------------------------
#
# Title: SEI Crypto Records 2-month High, Eyes To Hit $0.65 This Uptober?
# Source: coinpedia
# Published: 2024-09-21 17:59:17
# URL: https://coinpedia.org/price-analysis/sei-crypto-records-2-month-high-eyes-to-hit-0-65-this-uptober/
# Summary: The post SEI Crypto Records 2-month High, Eyes To Hit $0.65 This Uptober? appeared first on Coinpedia Fintech News With the Bitcoin price holding its value above the $63,000 mark, the crypto market co...
# --------------------------------------------------------------------------------
#
# Title: Pundit Predicts An ‘I Told You So Moment’ For Cardano As Price Signals $31 ADA Price Rocket
# Source: zycrypto
# Published: 2024-09-21 17:50:12
# URL: https://zycrypto.com/pundit-predicts-an-i-told-you-so-moment-for-cardano-as-price-signals-surge-to-31-ada-price/
# Summary: Cardano (ADA) kicked off the new week on a subdued note, as the broader crypto market experienced a downturn, led by Bitcoin. This drop saw the total crypto market cap shrink to $2.2 trillion. Notably...
# --------------------------------------------------------------------------------
#
# Title: Shibarium fees surge, top whale dumps 10K ETH, fueling top-performing presale interest
# Source: nft_news
# Published: 2024-09-21 17:49:00
# URL: https://crypto.news/shibarium-fees-surge-top-whale-dumps-10k-eth-fueling-top-performing-presale-interest/
# Summary: An Ethereum ICO participant sent 10,000 ETH to Kraken after two years. Shibarium fees soared 2,024% as IntelMarkets raises $450K. #partnercontent...
# --------------------------------------------------------------------------------
#
# Title: Shibarium fees surge, top whale dumps 10K ETH, fueling top-performing presale interest
# Source: crypto_news
# Published: 2024-09-21 17:49:00
# URL: https://crypto.news/shibarium-fees-surge-top-whale-dumps-10k-eth-fueling-top-performing-presale-interest/
# Summary: An Ethereum ICO participant sent 10,000 ETH to Kraken after two years. Shibarium fees soared 2,024% as IntelMarkets raises $450K. #partnercontent...
# --------------------------------------------------------------------------------
#
# Title: Arthur Hayes Speaks Out, Defends Himself About The Altcoin He First Advertised And Then Dumped
# Source: bitcoinsistemi
# Published: 2024-09-21 17:46:07
# URL: https://en.bitcoinsistemi.com/arthur-hayes-speaks-out-defends-himself-about-the-altcoin-he-first-advertised-and-then-dumped/
# Summary: Arthur Hayes, one of the well-known names in the cryptocurrency world, spoke about the altcoin that came to the fore with its recent sale. Continue Reading: Arthur Hayes Speaks Out, Defends Himself Ab...
# --------------------------------------------------------------------------------
#
# Title: BingX Suffers $52 Million Loss from Cyber Attack
# Source: cointurken
# Published: 2024-09-21 17:37:19
# URL: https://en.coin-turk.com/bingx-suffers-52-million-loss-from-cyber-attack/
# Summary: BingX lost $52 million due to a cyber attack. Multiple blockchains were exploited during the incident. Continue Reading: BingX Suffers $52 Million Loss from Cyber Attack The post BingX Suffers $52 Mil...
# --------------------------------------------------------------------------------
#
# Title: Supreme Court Regains Control of YouTube Channel After Hack By XRP Scammers
# Source: cryptointelligence
# Published: 2024-09-21 17:33:00
# URL: https://www.cryptointelligence.co.uk/supreme-court-regains-control-of-youtube-channel-after-hack-by-xrp-scammers/
# Summary: The Supreme Court of India regained control of its official YouTube account shortly after it was hijacked by cryptocurrency scammers selling fake XRP investments. On Sept. 20, the Supreme Court of Ind...
# --------------------------------------------------------------------------------
#
# Title: Billion-Dollar Bank Paying $27,760,000 Fine for Allegedly Placing Customers’ Access To Employment, Housing and Credit at Risk
# Source: dailyhodl
# Published: 2024-09-21 17:31:03
# URL: https://dailyhodl.com/2024/09/21/billion-dollar-bank-paying-27760000-fine-for-allegedly-placing-customers-access-to-employment-housing-and-credit-at-risk/
# Summary: The Consumer Financial Protection Bureau (CFPB) is accusing TD Bank of repeatedly placing its customers’ ability to access employment, housing and credit at risk. According to the US financial regulat...
# --------------------------------------------------------------------------------
#
# Title: Spot Bitcoin and Ether ETFs Record Second Day of Inflows, Leading to Gains
# Source: bitcoin.com
# Published: 2024-09-21 17:30:28
# URL: https://news.bitcoin.com/spot-bitcoin-and-ether-etfs-record-second-day-of-inflows-leading-to-gains/
# Summary: The spot bitcoin and ether exchange-traded funds (ETFs) experienced a second consecutive day of inflows, as both categories of funds posted gains. On Friday, spot bitcoin ETFs drew in $92 million, whi...
# --------------------------------------------------------------------------------
#
# Title: New Platform FXGuys ($FXG) Makes Its Case As A Superior Pick Over PEPE And XRP
# Source: themerkle
# Published: 2024-09-21 17:28:06
# URL: https://nulltx.com/new-platform-fxguys-fxg-makes-its-case-as-a-superior-pick-over-pepe-and-xrp/
# Summary: In recent weeks, new player FXGuys ($FXG) has been buzzing the crypto market with its innovative PropFi features and potential for 1000x returns. While seasonal tokens like Pepe (PEPE) have left inves...
# --------------------------------------------------------------------------------
#
# Title: Elon Musk made the worst financial decision of his life when he bought Twitter
# Source: cryptopolitan
# Published: 2024-09-21 17:25:30
# URL: https://www.cryptopolitan.com/elon-musk-worst-financial-decision-twitter/
# Summary: Elon Musk’s purchase of Twitter, now known as X, might be the biggest financial blunder he has ever made. The deal, which was finalized on October 27, 2022, came after a chaotic negotiation process th...
# --------------------------------------------------------------------------------
#
# Title: Weekly Economic Calendar: Bitcoin and Ethereum Highlights (Sept 23-28, 2024)
# Source: coinotag
# Published: 2024-09-21 17:23:21
# URL: https://en.coinotag.com/weekly-economic-calendar-bitcoin-and-ethereum-highlights-sept-23-28-2024/
# Summary: Get updated on the crucial economic releases this week and how they might impact Bitcoin and Ethereum prices....
# --------------------------------------------------------------------------------
#
# Title: MUSKPEPE Memecoin Will Rally 13,000% Ahead of Exchange Listing, While SHIB and BONK Fall
# Source: cryptointelligence
# Published: 2024-09-21 17:22:00
# URL: https://www.cryptointelligence.co.uk/muskpepe-memecoin-will-rally-13000-ahead-of-exchange-listing-while-shib-and-bonk-fall/
# Summary: Musk’s Pet Pepe could turn early investors into multi-millionaires, like Shiba Inu (SHIB) and Dogecoin (DOGE) did. Musk’s Pet Pepe (MUSKPEPE), a new Solana memecoin that was launched today, is poised ...
# --------------------------------------------------------------------------------
#
# Title: Coinbase's cbBTC wrapped Bitcoin coming to Solana — Breakpoint 2024
# Source: cointelegraph
# Published: 2024-09-21 17:10:57
# URL: https://cointelegraph.com/news/coinbase-s-cb-btc-wrapped-bitcoin-coming-to-solana?utm_source=rss_feed&utm_medium=rss&utm_campaign=rss_partner_inbound
# Summary: Wrapped Bitcoin products allow users to retain asset control while using Bitcoin as collateral for decentralized finance applications....
# --------------------------------------------------------------------------------
#
# Title: Ethereum to recover? Key signals indicate a surge in network activity!
# Source: ambcrypto
# Published: 2024-09-21 17:00:30
# URL: https://ambcrypto.com/ethereum-to-recover-key-signals-indicate-a-surge-in-network-activity/
# Summary: The recent sentiment shift in the market has renewed the prospects of interest in the Ethereum DeFi ecosystem. Here's what on-chain data has to say....
# --------------------------------------------------------------------------------
#
# Title: Internet Computer ICP price prediction 2024-2030: Is ICP a good investment?
# Source: cryptopolitan
# Published: 2024-09-21 16:56:48
# URL: https://www.cryptopolitan.com/icp-price-prediction/
# Summary: Key takeaways Internet Computer (ICP) is a groundbreaking blockchain network developed by the DFINITY Foundation. It aims to extend the functionality of the internet, enabling it to host backend softw...
# --------------------------------------------------------------------------------
#
# Title: Singapore-Based Crypto Exchange BingX Suffers $52,000,000 Hack: Blockchain Security Firm
# Source: dailyhodl
# Published: 2024-09-21 16:45:29
# URL: https://dailyhodl.com/2024/09/21/singapore-based-crypto-exchange-bingx-suffers-52000000-hack-blockchain-security-firm/
# Summary: New data from prominent blockchain security firm Cyvers reveals that a Singapore-based crypto exchange lost $52 million after being hacked. In a new post, Cyvers says that BingX’s hot wallet suffered ...
# --------------------------------------------------------------------------------
#
# Title: Solana and Binance Coin investors are adding Rollblock to their medium-term 100x prospects
# Source: nft_news
# Published: 2024-09-21 16:43:53
# URL: https://crypto.news/solana-and-binance-coin-investors-are-adding-rollblock-to-their-medium-term-100x-prospects/
# Summary: After strong gains, Solana and Binance Coin investors are eyeing Rollblock, seeking a potential 100x return in crypto. #partnercontent...
# --------------------------------------------------------------------------------
#
# Title: Solana and Binance Coin investors are adding Rollblock to their medium-term 100x prospects
# Source: crypto_news
# Published: 2024-09-21 16:43:53
# URL: https://crypto.news/solana-and-binance-coin-investors-are-adding-rollblock-to-their-medium-term-100x-prospects/
# Summary: After strong gains, Solana and Binance Coin investors are eyeing Rollblock, seeking a potential 100x return in crypto. #partnercontent...
# --------------------------------------------------------------------------------
#
# Title: ECB president Christine Lagarde says the global economy is headed for recession
# Source: cryptopolitan
# Published: 2024-09-21 16:35:14
# URL: https://www.cryptopolitan.com/ecb-president-christine-lagarde-says-the-global-economy-is-headed-for-recession/
# Summary: Christine Lagarde, the head of the European Central Bank, believes the global economy is in deep trouble, and about to hit a recession. She drew comparisons to the 1920s, when economic instability and...
# --------------------------------------------------------------------------------
#
# Title: Crypto experts believe this altcoin will massively outperform Dogecoin and XRP
# Source: nft_news
# Published: 2024-09-21 16:32:08
# URL: https://crypto.news/crypto-experts-believe-this-altcoin-will-massively-outperform-dogecoin-and-xrp/
# Summary: New altcoin Rollblock is gaining traction, raising $3.7 million in presale and challenging Dogecoin and XRP. #partnercontent...
# --------------------------------------------------------------------------------
#
# Title: Crypto experts believe this altcoin will massively outperform Dogecoin and XRP
# Source: crypto_news
# Published: 2024-09-21 16:32:08
# URL: https://crypto.news/crypto-experts-believe-this-altcoin-will-massively-outperform-dogecoin-and-xrp/
# Summary: New altcoin Rollblock is gaining traction, raising $3.7 million in presale and challenging Dogecoin and XRP. #partnercontent...
# --------------------------------------------------------------------------------
#
# Title: Magic Eden Plans to Launch ME Token on Solana Blockchain
# Source: bitcoinworld
# Published: 2024-09-21 16:31:25
# URL: https://bitcoinworld.co.in/magic-eden-plans-to-launch-me-token-on-solana/
# Summary: Magic Eden Plans to Launch ME Token on Solana Blockchain In a move that could significantly enhance its ecosystem, Magic Eden, a leading NFT marketplace, is planning to launch its native ME token on t...
# --------------------------------------------------------------------------------
#
# Title: QCP Capital: Crypto Rally Extends, Supported by ETF Inflows
# Source: bitcoin.com
# Published: 2024-09-21 16:30:30
# URL: https://news.bitcoin.com/qcp-capital-crypto-rally-extends-supported-by-etf-inflows/
# Summary: Bitcoin (BTC) and ether (ETH) surged for a third consecutive day, supported by strong inflows into spot exchange-traded funds (ETFs), according to a weekend analysis by QCP Capital. The firm reported ...
# --------------------------------------------------------------------------------
#
# Title: Crypto VC funding: The Open Network raises $30M, Drift Protocol brings in $25M
# Source: nft_news
# Published: 2024-09-21 16:26:00
# URL: https://crypto.news/crypto-vc-funding-the-open-network-raises-30m-drift-protocol-brings-in-25m/
# Summary: Our crypto VC funding column, for the week of Sept. 15 to Sept. 21, explores the latest capital-raising efforts: Open Network, Drift Protocol, Helius, Hemi Labs and Pipe Network....
# --------------------------------------------------------------------------------
#
# Title: Crypto VC funding: The Open Network raises $30M, Drift Protocol brings in $25M
# Source: crypto_news
# Published: 2024-09-21 16:26:00
# URL: https://crypto.news/crypto-vc-funding-the-open-network-raises-30m-drift-protocol-brings-in-25m/
# Summary: Our crypto VC funding column, for the week of Sept. 15 to Sept. 21, explores the latest capital-raising efforts: Open Network, Drift Protocol, Helius, Hemi Labs and Pipe Network....
# --------------------------------------------------------------------------------
#
# Title: Bittensor price prediction 2024–2030: Is TAO a good investment?
# Source: cryptopolitan
# Published: 2024-09-21 16:24:00
# URL: https://www.cryptopolitan.com/bittensor-price-prediction/
# Summary: Key takeaways Bittensor is a decentralized artificial intelligence-based network that integrates blockchain technology with AI. It uses Proof of Learning (PoL) to make sure nodes provide reliable AI m...
# --------------------------------------------------------------------------------
#
# Title: XRP Price Prediction as Investors Await Ripple Swell & SEC Appeal
# Source: coingape
# Published: 2024-09-21 16:21:15
# URL: https://coingape.com/markets/xrp-price-prediction-investors-ripple-swell-sec-appeal/
# Summary: XRP price prediction reported a 3.4% surge during the Saturday session, teasing a bullish breakout from the $0.6 resistance. The sudden inflow could be linked to Vice President Kamala Harris accepting...
# --------------------------------------------------------------------------------
#
# Title: NEAR Protocol Price Eyes 120% Surge, Is it Poised for Massive Growth?
# Source: coingape
# Published: 2024-09-21 16:20:46
# URL: https://coingape.com/markets/near-protocol-price-eyes-120-surge-is-it-poised-for-massive-growth/
# Summary: NEAR Protocol (NEAR), a layer-one blockchain, has experienced a significant uptick in its market value recently. This surge indicates potential for further increases as the asset continues to exhibit ...
# --------------------------------------------------------------------------------
#
# Title: Germany Shuts Down 47 Crypto Exchanges Over Money Laundering Activities
# Source: cryptopotato
# Published: 2024-09-21 16:16:43
# URL: https://cryptopotato.com/germany-shuts-down-47-crypto-exchanges-over-money-laundering-activities/
# Summary: Authorities have obtained servers containing IP addresses of the criminals and are on the hunt for them....
# --------------------------------------------------------------------------------
#
# Title: 3 cryptocurrencies to turn $100 into $5,000: ‘Sell your watch’
# Source: finbold
# Published: 2024-09-21 16:15:29
# URL: https://finbold.com/3-cryptocurrencies-to-turn-100-into-5000-sell-your-watch/
# Summary: A cryptocurrency influencer, venture capitalist, and angel investor recommended his followers to “sell your watch” and put in one of … Continue reading The post 3 cryptocurrencies to turn $100 into $5...
# --------------------------------------------------------------------------------
#
# Title: Ethereum Dominates NFT Sales Amid Market Surge, Despite Weekly Dip
# Source: coinotag
# Published: 2024-09-21 16:14:37
# URL: https://en.coinotag.com/ethereum-dominates-nft-sales-amid-market-surge-despite-weekly-dip/
# Summary: The NFT market experienced a resurgence between Sept. 14-21, 2024, following weeks of lackluster performance. Sales across 21 blockchains surged to $77.13 million, representing a 7.33% increase, accor...
# --------------------------------------------------------------------------------
#
# Title: BNY Mellon Exemption May Pave Way for U.S. Banks to Offer Bitcoin Custody
# Source: btcpulse
# Published: 2024-09-21 16:12:42
# URL: https://btc-pulse.com/bny-mellon-exemption-may-pave-way-u-s-banks/
# Summary: BNY Mellon’s exemption from SEC SAB 121 may allow U.S. banks to custody Bitcoin, possibly signaling a shift in the federal stance on cryptocurrency....
# --------------------------------------------------------------------------------
#
# Title: PS5 pro backlash sparks a new PlayStation vs PC debate
# Source: cryptopolitan
# Published: 2024-09-21 16:12:13
# URL: https://www.cryptopolitan.com/ps5-pro-backlash-sparks-a-new-playstation-vs-pc-debate/
# Summary: PS5 pro was recently announced with upgraded specifications, and a high price. This revived the decade long debate between PC and PlayStation fanbase. PS5 pro was announced at a starting price of $700...
# --------------------------------------------------------------------------------
#
# Title: Trump Bull Market Memecoin to Surge 19,000% Ahead of Exchange Listings, as Shiba Inu and DOGE Struggle
# Source: cryptointelligence
# Published: 2024-09-21 16:05:00
# URL: https://www.cryptointelligence.co.uk/trump-bull-market-memecoin-to-surge-19000-ahead-of-exchange-listings-as-shiba-inu-and-doge-struggle/
# Summary: Trump Bull Market could turn early investors into multi-millionaires, like Shiba Inu (SHIB) and Dogecoin (DOGE) did. Trump Bull Market (TRUMBULL), a new Solana memecoin that was launched recently, is ...
# --------------------------------------------------------------------------------
#
# Title: Dogecoin Eyes 20% Rally, On-chain Data Flashes Bullish Signal
# Source: coinpedia
# Published: 2024-09-21 16:04:42
# URL: https://coinpedia.org/news/dogecoin-eyes-20-rally-on-chain-data-flashes-bullish-signal/
# Summary: The post Dogecoin Eyes 20% Rally, On-chain Data Flashes Bullish Signal appeared first on Coinpedia Fintech News Dogecoin (DOGE) the world’s biggest meme coin by market cap is poised for a significant ...
# --------------------------------------------------------------------------------
#
# Title: SUI Continues Bullish Run, Surges 45% In The Past Week — What Next?
# Source: newsbtc
# Published: 2024-09-21 16:00:49
# URL: https://www.newsbtc.com/sui/sui-continues-bullish-run-surges-45-in-the-past-week-what-next/
# Summary: The interest rate cut by the US Federal Reserve has been one of the biggest stories in the crypto space this week, with most large-cap assets making something of a recovery in the past few days. As a ...
# --------------------------------------------------------------------------------
#
# Title: VanEck: Why a Kamala Harris presidency could be better for Bitcoin
# Source: ambcrypto
# Published: 2024-09-21 16:00:14
# URL: https://ambcrypto.com/vaneck-why-a-kamala-harris-presidency-could-be-better-for-bitcoin/
# Summary: VanEck has made a contrarian bet on BTC if Harris wins 2024 US elections...
# --------------------------------------------------------------------------------
#
# Title: BlackRock CEO Larry Fink Makes Bullish Remarks on Bitcoin
# Source: bitcoinsistemi
# Published: 2024-09-21 15:55:09
# URL: https://en.bitcoinsistemi.com/blackrock-ceo-larry-fink-makes-bullish-remarks-on-bitcoin/
# Summary: Larry Fink, CEO of BlackRock, the world's largest asset manager, spoke about Bitcoin in his statement. Continue Reading: BlackRock CEO Larry Fink Makes Bullish Remarks on Bitcoin...
# --------------------------------------------------------------------------------
#
# Title: Ethereum Name Service price prediction 2024-2030: Is ENS a good investment?
# Source: cryptopolitan
# Published: 2024-09-21 15:38:54
# URL: https://www.cryptopolitan.com/ethereum-name-service-price-prediction/
# Summary: Key takeaways Ethereum Name Service is a network that allows crypto-enthusiasts to rename their crypto addresses into something more uncomplicated for them to remember easily. Renaming crypto addresse...
# --------------------------------------------------------------------------------
#
# Title: Kamala Harris Accepts Second Presidential Debate Challenge from Pro-Crypto Trump
# Source: coinotag
# Published: 2024-09-21 15:37:35
# URL: https://en.coinotag.com/kamala-harris-accepts-second-presidential-debate-challenge-from-pro-crypto-trump/
# Summary: The cryptocurrency market remains a vibrant topic with continuous developments and significant impacts on global finance. Recent movements in Bitcoin and Ethereum prices have caught the attention of i...
# --------------------------------------------------------------------------------
#
# Title: NFT Sales Climb 7.33%, Mythos, Blast, and Solana Lead the Charge
# Source: bitcoin.com
# Published: 2024-09-21 15:34:55
# URL: https://news.bitcoin.com/nft-sales-climb-7-33-mythos-blast-and-solana-lead-the-charge/
# Summary: Non-fungible tokens (NFTs) had quite the boost this week, with sales climbing by 7.33% compared to the previous one, totaling $77.13 million. The number of NFT sellers skyrocketed by 95.68%, while buy...
# --------------------------------------------------------------------------------
#
# Title: US Paying $1,157,762,000,000 in Interest on National Debt in One Year, Says Treasury Department, As Elon Musk Warns Government ‘Whistling Past the Graveyard’
# Source: dailyhodl
# Published: 2024-09-21 15:31:45
# URL: https://dailyhodl.com/2024/09/21/us-paying-1157762000000-in-interest-on-national-debt-in-one-year-says-treasury-department-as-elon-musk-warns-government-whistling-past-the-graveyard/
# Summary: The US Treasury Department says it expects to pay a whopping $1.157762 trillion in interest on the national debt for the fiscal year 2024. The interest represents the cost of borrowing money, which th...
# --------------------------------------------------------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
news_df.to_csv('cryptonews.csv', index=False)

# %%
news = pd.read_csv("cryptonews.csv")

# %%
news.head()
# Out:
#                                                title         source  \
# 0  Rich Dad Poor Dad Author Tells Us Why Bitcoin ...       zycrypto
# 1  Hashgraph Association to Explore Five Crypto U...       btcpulse
# 2  Polkadot Price Prediction 2024-2030: A Bullish...  cryptopolitan
# 3  US Judge Orders Convicted Fraudster To Pay $36...      dailyhodl
# 4  Is XRP supply running low? Here’s what it mean...      ambcrypto
#
#           published_on                                                url  \
# 0  2024-09-21 18:16:26  https://zycrypto.com/rich-dad-poor-dad-author-...
# 1  2024-09-21 18:03:00  https://btc-pulse.com/hashgraph-association-ex...
# 2  2024-09-21 18:01:31  https://www.cryptopolitan.com/polkadot-price-p...
# 3  2024-09-21 18:00:31  https://dailyhodl.com/2024/09/21/us-judge-orde...
# 4  2024-09-21 18:00:28  https://ambcrypto.com/is-xrp-supply-running-lo...
#
#                                                 body
# 0  Robert Kiyosaki, the best-selling author of “R...
# 1  The Hashgraph Association partners with Qatar ...
# 2  Key takeaways: Polkadot (DOT), known for its i...
# 3  A US judge this week ordered a convicted fraud...
# 4  XRP supply is rapidly shrinking as institution...

# %%
print(news.shape)
# Out:
# (50, 5)

# %%
# Out:
#                                                title         source  \
# 0  Rich Dad Poor Dad Author Tells Us Why Bitcoin ...       zycrypto
# 1  Hashgraph Association to Explore Five Crypto U...       btcpulse
# 2  Polkadot Price Prediction 2024-2030: A Bullish...  cryptopolitan
# 3  US Judge Orders Convicted Fraudster To Pay $36...      dailyhodl
# 4  Is XRP supply running low? Here’s what it mean...      ambcrypto
#
#           published_on                                                url  \
# 0  2024-09-21 18:16:26  https://zycrypto.com/rich-dad-poor-dad-author-...
# 1  2024-09-21 18:03:00  https://btc-pulse.com/hashgraph-association-ex...
# 2  2024-09-21 18:01:31  https://www.cryptopolitan.com/polkadot-price-p...
# 3  2024-09-21 18:00:31  https://dailyhodl.com/2024/09/21/us-judge-orde...
# 4  2024-09-21 18:00:28  https://ambcrypto.com/is-xrp-supply-running-lo...
#
#                                                 body
# 0  Robert Kiyosaki, the best-selling author of “R...
# 1  The Hashgraph Association partners with Qatar ...
# 2  Key takeaways: Polkadot (DOT), known for its i...
# 3  A US judge this week ordered a convicted fraud...
# 4  XRP supply is rapidly shrinking as institution...
